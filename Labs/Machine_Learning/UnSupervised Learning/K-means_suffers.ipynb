# %% [markdown]
# # Import Libaries

# %%
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.spatial import distance
from scipy import linalg
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from sklearn.neighbors import kneighbors_graph
from sklearn.metrics import silhouette_score
from sklearn.metrics.cluster import adjusted_rand_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Generate Data

# %%
x,y=datasets.make_moons(n_samples=500, noise=.1)

# %%
sns.scatterplot(x[:,0],x[:,1],hue=y)

# %% [markdown]
# # Train And Test

# %% [markdown]
# ## Kmeans

# %%
kmean=KMeans(2,init='k-means++')
kmean_y=kmean.fit_predict(x)

# %%
sns.scatterplot(x[:,0],x[:,1],hue=kmean_y)

# %%
print('silhouette= ',silhouette_score(x, kmean_y, metric='euclidean'))
print('adjusted rand= ',adjusted_rand_score(y, kmean_y))
# Out:
# silhouette=  0.49184404460708453
# adjusted rand=  0.26478264209533675

# %% [markdown]
# ## SpectralClustering

# %%
sc = SpectralClustering(2,affinity='nearest_neighbors',assign_labels='kmeans')
sk_y=sc.fit_predict(x)

# %%
sns.scatterplot(x[:,0],x[:,1],hue=sk_y)

# %%
print('silhouette= ',silhouette_score(x, sk_y, metric='euclidean'))
print('adjusted rand= ',adjusted_rand_score(y, sk_y))
# Out:
# silhouette=  0.34261512391720933
# adjusted rand=  0.9524808260462735
